# %% [markdown]
# # _CellExplorer and H5see usage_

# %% [markdown]
# ## _Get CellExplorer and H5see_
# `git clone https://github.com/European-XFEL/CrystFEL-Jupyter-utilities.git`

# %% [markdown]
# ## _get needed files_
# we need:
# > - file with geometry `http://www.desy.de/~twhite/crystfel/5HT2B-Liu-2013.geom`
# > - some data from LCLS `http://www.cxidb.org/id-21.html`
# > - some file with extract and view the peak list information `indexamajig -i files.lst -g 5HT2B-Liu-2013.geom --peaks=hdf5 --indexing=mosflm --int-radius=3,4,5 -o Process.stream`

# %% [markdown]
# ## _Run CellExplorer_

# %%
from CrystFEL_Jupyter_utilities.GUI_tools import CellExplorer

# %% [markdown]
# #### Notebook magic:

# %%
# %matplotlib notebook
# interactive mode

# %% [markdown]
# ### _Run the program with python tool similar to_ _cell_ _ _explorer:_

# %%
# path to the file with the extension .stream
streamfile = 'Process.stream'

# %%
RUN = CellExplorer(streamfile)
# Out:
# <img src="data:image/png;base64,..." width="640">
# INFO | stream_read.py | search_crystals_parameters | 220 | Loaded 5616 cells from 8127 chunks

# %% [markdown]
# ### _another way to run program_
# immediately marked areas on the histogram parametrs <a>, b, c, alfa, beta, gamma

# %%
streamfile = 'Process.stream'

# %%
RUN = CellExplorer(streamfile, alfa=(80, 100),beta=(80, 100),gamma=(80, 100))
# Out:
# <img src="data:image/png;base64,..." width="640">
# INFO | stream_read.py | search_crystals_parameters | 220 | Loaded 5616 cells from 8127 chunks
#
# INFO | widget.py | onselect | 728 | Selected 5132 of 5616 cells
#
# INFO | widget.py | onselect | 728 | Selected 4754 of 5616 cells
#
# INFO | widget.py | onselect | 728 | Selected 2994 of 5616 cells

# %% [markdown]
# ## _Run H5see_

# %% [markdown]
# #### Notebook magic:

# %%
# %matplotlib notebook
# interactive mode

# %% [markdown]
# ### Display the image with python tool similar to hdfsee:
# path to the LCLS file `/mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_20b5.h5`

# %% [markdown]
# Picture in the form of not arranged panels

# %%
from CrystFEL_Jupyter_utilities.hdfsee import Image

# %%
image_run = Image(path="/mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_20b5.h5")
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# ## _With geometry file_
# path to the LCLS file
#
# -g argument for the geometry file, path to the geomtry file
#
# Picture in the form of arranged panels

# %%
image_run_geometry = Image(path="/mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_2085.h5",
                           geomfile="5HT2B-Liu-2013.geom")
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# ## _With geometry and stream file_
# path to the LCLS file
#
# -g argument for the geometry file, path to the geomtry file
#
# -p argument for the stream file, path to the stream file
#
# Picture in the form of arranged panels and peaks from stream file

# %%
image_run_stream = Image(path="/mnt/home/tsachanowski/data/cxidb-21-run0133/data1/LCLS_2013_Mar23_r0133_010458_17673.h5",
                         geomfile="5HT2B-Liu-2013.geom",
                         streamfile="Process.stream")
# Out:
# <img src="data:image/png;base64,..." width="950">
