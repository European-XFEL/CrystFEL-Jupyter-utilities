# %% [markdown]
# # _CellExplorer and H5see usage_

# %% [markdown]
# ## _Get CellExplorer and H5see_
# `git clone git@code.cis.gov.pl:tsachanowski/h5see_public.git`

# %% [markdown]
# ## _get needed files_
# we need:
# > - file with geometry `http://www.desy.de/~twhite/crystfel/5HT2B-Liu-2013.geom`
# > - some data from LCLS `http://www.cxidb.org/id-21.html`
# > - some file with extract and view the peak list information `indexamajig -i files.lst -g 5HT2B-Liu-2013.geom --peaks=hdf5 --indexing=mosflm --int-radius=3,4,5 -o Process.stream`

# %% [markdown]
# ## _Run CellExplorer_

# %%
from GUI_tools import CellExplorer

# %% [markdown]
# #### Notebook magic:

# %%
# %matplotlib notebook
# interactive mode

# %% [markdown]
# ### _Run the program with python tool similar to_ _cell_ _ _explorer:_

# %%
# path to the file with the extension .stream
streamfile = '/mnt/home/tsachanowski/h5see_public/Process.stream'

# %%
RUN = CellExplorer(streamfile)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# Loaded 5616 cells from 8127 chunks
# /mnt/home/tsachanowski/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### _another way to run program_
# immediately marked areas on the histogram parametrs <a>, b, c, alfa, beta, gamma

# %%
streamfile = '/mnt/home/tsachanowski/h5see_public/Process.stream'

# %%
RUN = CellExplorer(streamfile, alfa=(80, 90),beta=(80, 90),gamma=(80, 90))
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# Loaded 5616 cells from 8127 chunks
# /mnt/home/tsachanowski/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Selected 2959 of 5616 cells
# Selected 1285 of 5616 cells
# Selected 305 of 5616 cells

# %% [markdown]
# ## _Run H5see_

# %% [markdown]
# #### Notebook magic:

# %%
# %matplotlib notebook
# interactive mode

# %% [markdown]
# ### Display the image with python tool similar to hdfsee:
# path to the LCLS file `/mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_20b5.h5`

# %% [markdown]
# Picture in the form of not arranged panels

# %%
# %run  'hdfsee.py'  /mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_20b5.h5
# Out:
# /mnt/home/tsachanowski/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <img src="data:image/png;base64,..." width="999.4166666666666">

# %% [markdown]
# ## _With geometry file_
# path to the LCLS file
#
# -g argument for the geometry file, path to the geomtry file
#
# Picture in the form of arranged panels

# %%
# %run  'hdfsee.py'  /mnt/home/tsachanowski/data/cxidb-21-run0135/data1/LCLS_2013_Mar23_r0135_015531_20b5.h5 -g 5HT2B-Liu-2013.geom
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">

# %% [markdown]
# ## _With geometry and stream file_
# path to the LCLS file
#
# -g argument for the geometry file, path to the geomtry file
#
# -p argument for the stream file, path to the stream file
#
# Picture in the form of arranged panels and peaks from stream file

# %%
# %run  'hdfsee.py' /mnt/home/tsachanowski/data/cxidb-21-run0133/data1/LCLS_2013_Mar23_r0133_010458_17673.h5 -g 5HT2B-Liu-2013.geom -p /mnt/home/tsachanowski/h5see_public/Process.stream
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">
